# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/Glass%20Identification/Glass%20Identification.csv")

# %% [markdown]
# <font size='5'>**Dataset Information**

# %%
df
# Out:
#        1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.00.1  1.1
# 0      2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00    0.00    1
# 1      3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00    0.00    1
# 2      4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00    0.00    1
# 3      5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00    0.00    1
# 4      6  1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.00    0.26    1
# ..   ...      ...    ...   ...   ...    ...   ...   ...   ...     ...  ...
# 208  210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06    0.00    7
# 209  211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59    0.00    7
# 210  212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64    0.00    7
# 211  213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57    0.00    7
# 212  214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67    0.00    7
#
# [213 rows x 11 columns]

# %% [markdown]
# We saw a extra column (1st Column) So, we drop 1st column.

# %%
df.drop(df.columns[[0]], axis=1, inplace=True)

# %%
df
# Out:
#      1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.00.1  1.1
# 0    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00    0.00    1
# 1    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00    0.00    1
# 2    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00    0.00    1
# 3    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00    0.00    1
# 4    1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.00    0.26    1
# ..       ...    ...   ...   ...    ...   ...   ...   ...     ...  ...
# 208  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06    0.00    7
# 209  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59    0.00    7
# 210  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64    0.00    7
# 211  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57    0.00    7
# 212  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67    0.00    7
#
# [213 rows x 10 columns]

# %% [markdown]
# This data doesn't have any headings such as attribute names, so we add attribute headings to the data from glass names.

# %%
df.columns = ['Ri','Na','Mg','Al','Si','K','Ca','Ba','Fe','Type']

# %%
df
# Out:
#           Ri     Na    Mg    Al     Si     K    Ca    Ba    Fe  Type
# 0    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.00     1
# 1    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.00     1
# 2    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.00     1
# 3    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.00     1
# 4    1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.00  0.26     1
# ..       ...    ...   ...   ...    ...   ...   ...   ...   ...   ...
# 208  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.00     7
# 209  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.00     7
# 210  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.00     7
# 211  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.00     7
# 212  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.00     7
#
# [213 rows x 10 columns]

# %% [markdown]
# We have sucessfully added attribute names at the top.

# %% [markdown]
# # Check Missing Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213 entries, 0 to 212
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Ri      213 non-null    float64
#  1   Na      213 non-null    float64
#  2   Mg      213 non-null    float64
#  3   Al      213 non-null    float64
#  4   Si      213 non-null    float64
#  5   K       213 non-null    float64
#  6   Ca      213 non-null    float64
#  7   Ba      213 non-null    float64
#  8   Fe      213 non-null    float64
#  9   Type    213 non-null    int64
# dtypes: float64(9), int64(1)
# memory usage: 16.8 KB

# %% [markdown]
# This clearly states that there are 213 non-null count in all the columns.

# %%
df.describe()
# Out:
#                Ri          Na          Mg          Al          Si           K  \
# count  213.000000  213.000000  213.000000  213.000000  213.000000  213.000000
# mean     1.518353   13.406761    2.676056    1.446526   72.655023    0.499108
# std      0.003039    0.818371    1.440453    0.499882    0.774052    0.653035
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516520   12.900000    2.090000    1.190000   72.280000    0.130000
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.560000
# 75%      1.519150   13.830000    3.600000    1.630000   73.090000    0.610000
# max      1.533930   17.380000    3.980000    3.500000   75.410000    6.210000
#
#                Ca          Ba          Fe        Type
# count  213.000000  213.000000  213.000000  213.000000
# mean     8.957934    0.175869    0.057277    2.788732
# std      1.426435    0.498245    0.097589    2.105130
# min      5.430000    0.000000    0.000000    1.000000
# 25%      8.240000    0.000000    0.000000    1.000000
# 50%      8.600000    0.000000    0.000000    2.000000
# 75%      9.180000    0.000000    0.100000    3.000000
# max     16.190000    3.150000    0.510000    7.000000

# %% [markdown]
# Hence, this data set has no null values and all the attribute values are numerical.

# %% [markdown]
# # Data Analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.subplots(figsize = (25,12))
sns.countplot(x='Type', data = df).set_title('Counting Glass Types')
sns.set(style='whitegrid', font_scale=5)

# %% [markdown]
# # Type of glass: (class attributes)

# %% [markdown]
#      1 - building_windows_float_processed
#      2 - building_windows_non_float_processed
#      3 - vehicle_windows_float_processed
#      4 - vehicle_windows_non_float_processed (none in this database)
#      5 - containers
#      6 - tableware
#      7 - headlamps

# %% [markdown]
# This clearly shows, type 1 and 2 having high count since, windows of the building are involved in high criminal cases.

# %%
sns.set(style="darkgrid", font_scale=1.5)
f, axes = plt.subplots(3,figsize = (20,15))
sns.boxplot(x='Type', y='Ri', data=df , ax=axes[0])
sns.boxplot(x='Type', y='Na', data=df , ax=axes[1])
sns.boxplot(x='Type', y='Mg', data=df , ax=axes[2])
plt.show()

# %%
sns.set(style="darkgrid", font_scale=1.5)
f, axes = plt.subplots(3,figsize = (20,15))
sns.boxplot(x='Type', y='Al', data=df , ax=axes[0])
sns.boxplot(x='Type', y='Si', data=df , ax=axes[1])
sns.boxplot(x='Type', y='K', data=df , ax=axes[2])
plt.show()

# %%
sns.set(style="darkgrid", font_scale=1.5)
f, axes = plt.subplots(3,figsize = (20,15))
sns.boxplot(x='Type', y='Ca', data=df , ax=axes[0])
sns.boxplot(x='Type', y='Ba', data=df , ax=axes[1])
sns.boxplot(x='Type', y='Fe', data=df , ax=axes[2])
plt.show()

# %% [markdown]
# These boxplots show:
#
#   -Refractive index being high in Type-5 i.e, containers.
#
#   -Sodium being higher in Type-6(table ware) and Type-7(head lamps).
#
#   -Magnesium being higher in windows of buildings and class glass.
#
#   -Calcium is higher in container glass.
#
#   -Barium is only in headlamps.
#
#   -Iron content is only in Type-1,2,3 i.e, building_windows_float_processed, building_windows_non_float_processed,
#     vehicle_windows_float_processed

# %% [markdown]
# # Correlation

# %%
plt.subplots(figsize=(20,15))
sns.heatmap(df.corr(), annot = True)
# Out:
# <Axes: >

# %% [markdown]
# <font size='3'> **From the correlation heatmap, we can see that**

# %% [markdown]
#  - Calsium and refractive index has high positive correlation(0.81).
#
#
#  - Sillicon and refractive index has high negative correlation(-0.54).

# %%
sns.pairplot(df[['Ri','Na','Mg','Al','Si','Ca']], kind='reg')
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn import tree
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %% [markdown]
# # Split Data for Training and Testing

# %%
X = df.drop(['Type'],axis=1)
Y=df['Type'].values

# %%
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=.3,random_state=25)

# %% [markdown]
# We should check weather the test and train has all glass type values.

# %%
print(np.unique(y_train))
print(np.unique(y_test))
# Out:
# [1 2 3 5 6 7]
# [1 2 3 5 6 7]

# %% [markdown]
# # Apply different Classification Algorithms

# %% [markdown]
# <font size='4'>**Decision Tree**

# %%
d_tree = tree.DecisionTreeClassifier()
d_tree.fit(x_train, y_train)
y_pred = d_tree.predict(x_test)
decision_tree = metrics.accuracy_score(y_pred,y_test)

# %% [markdown]
# <font size='4'>**Random Forest**

# %%
Rand_f = RandomForestClassifier(max_depth = 3, min_samples_split=2, n_estimators = 50, random_state = 1)
Rand_f.fit(x_train, y_train)
y_pred = Rand_f.predict(x_test)
random_forest = metrics.accuracy_score(y_pred,y_test)

# %% [markdown]
# <font size='4'>**Support Vector Machine**

# %%
svm  = SVC()
svm.fit(x_train,y_train)
y_pred = svm.predict(x_test)
s_vector  = metrics.accuracy_score(y_pred,y_test)

# %% [markdown]
# <font size='3'> **Get performance metrics for all the applied classifiers**

# %%
pd.DataFrame([['Decision Tree',decision_tree]], columns = ['Model','Accuracy'])
# Out:
#            Model  Accuracy
# 0  Decision Tree    0.6875

# %%
pd.DataFrame([['Random Forest',random_forest]], columns = ['Model','Accuracy'])
# Out:
#            Model  Accuracy
# 0  Random Forest      0.75

# %%
pd.DataFrame([['Support Vector Machines',s_vector]], columns = ['Model','Accuracy'])
# Out:
#                      Model  Accuracy
# 0  Support Vector Machines  0.390625

# %% [markdown]
# Clearly we can see Random forest has high accuracy than remain classifier.

# %% [markdown]
# # Hyper Tuning

# %%
param_grid = { "criterion" : ["gini", "entropy"]
              , "min_samples_leaf" : [1, 5, 10]
              , "min_samples_split" : [2, 4, 10, 12, 16]
              , "n_estimators": [100, 125, 200]}
grid = GridSearchCV(estimator = Rand_f,param_grid=param_grid, cv=5, scoring='accuracy')
grid.fit(x_train, y_train)
print("Best parameters set are:")
print()
print(grid.best_params_)
# Out:
# Best parameters set are:
#
# {'criterion': 'entropy', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}

# %% [markdown]
# <font size='3'> **Running the final model**

# %%
model = grid.best_estimator_
model.fit(x_train,y_train)
y_pred = model.predict(x_test)
metrics.accuracy_score(y_pred,y_test)
# Out:
# 0.75

# %% [markdown]
# # Model Performance

# %%
matrix = confusion_matrix(y_test, y_pred)
plt.subplots(figsize=(20,10))
sns.heatmap(matrix.T, square=True, annot=True, fmt='d', cbar=False)
plt.xlabel('True label')
plt.ylabel('Predicted label')
# Out:
# Text(601.25, 0.5, 'Predicted label')

# %% [markdown]
# # Model Implementation

# %%
forest_mod = RandomForestClassifier(min_samples_leaf= 1, min_samples_split= 2, n_estimators= 100)
forest_mod.fit(X.iloc[:,0:9],Y)
# Out:
# RandomForestClassifier()

# %%
from IPython.display import display
def find(Ri,Na,Mg,Al,Si,K,Ca,Ba,Fe):
    y_values = forest_mod.predict([[Ri,Na,Mg,Al,Si,K,Ca,Ba,Fe]])
    print("The Glass Type is {}".format(y_values))

# %%
find(1.51761,13.89,3.60,1.36,72.73,0.48,7.83,0.00,0.00)
# Out:
# The Glass Type is [1]
# C:\Users\dell\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
